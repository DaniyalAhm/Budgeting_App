# %%
import pandas as pd

# Load the dataset (assuming it's in CSV format)
df = pd.read_csv('backend/holidays_events.csv')

# Display the first few rows to understand the structure
print(df.head())

# Example of formatting the data for Prophet
df['ds'] = pd.to_datetime(df['date_column_name'])  # Replace 'date_column_name' with your actual column name
df['y'] = df['target_column_name']  # Replace 'target_column_name' with your actual target column

# Keep only the necessary columns
df = df[['ds', 'y']]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 4
#       1 import pandas as pd
#       3 # Load the dataset (assuming it's in CSV format)
# ----> 4 df = pd.read_csv('path_to_your_dataset.csv')
#       6 # Display the first few rows to understand the structure
#       7 print(df.head())
#
# ...

# %%
# Initialize the model
model = Prophet()

# Fit the model
model.fit(df)
# Out:
# 00:33:13 - cmdstanpy - INFO - Chain [1] start processing
# 00:33:13 - cmdstanpy - INFO - Chain [1] done processing

# %%
# Create a DataFrame with future dates
future = model.make_future_dataframe(periods=12, freq='M')  # Predicting 12 months ahead

# Make predictions
forecast = model.predict(future)
# Out:
# /home/daniyal/.local/lib/python3.12/site-packages/prophet/forecaster.py:1854: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(

# %%
# Plot the forecast
model.plot(forecast)
plt.show()

# Optional: Plot the forecast components
model.plot_components(forecast)
plt.show()
# Out:
# /home/daniyal/.local/lib/python3.12/site-packages/prophet/plot.py:72: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# /home/daniyal/.local/lib/python3.12/site-packages/prophet/plot.py:73: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   ax.plot(m.history['ds'].dt.to_pydatetime(), m.history['y'], 'k.',
# ...

# %%
print(forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail())
# Out:
#            ds        yhat  yhat_lower  yhat_upper
# 12 2023-12-31  375.269153  358.048729  391.687784
# 13 2024-01-31  398.241342  382.297192  417.032920
# 14 2024-02-29  419.731453  402.634568  436.433185
# 15 2024-03-31  442.703642  426.724757  460.111357
# 16 2024-04-30  464.934791  448.197565  481.603837
